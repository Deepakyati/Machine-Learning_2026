# %% [markdown]
# # Home Price Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model

# %%
df = pd.read_csv('HousePrice - Sheet1.csv')
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area in sqft')
plt.ylabel('Price in USD')

plt.scatter(df.Area, df.Price, color ='red')

# %%
#lr means linear regression

lr=linear_model.LinearRegression()

# %%
lr.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
lr.predict([[3000]])
# Out:
# C:\Users\Deepak18\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
lr.coef_
# Out:
# array([135.78767123])

# %%
lr.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
lr.predict([[5000]])
# Out:
# C:\Users\Deepak18\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d=pd.read_csv('1PricePrediction - Sheet1.csv')
d
# Out:
#     Area
# 0   1000
# 1   1200
# 2   2300
# 3   3400
# 4   4500
# 5   5600
# 6   3400
# 7   3456
# 8   5678
# 9   5432
# 10  6789

# %%
#prices 

lr.predict(d)
# Out:
# array([ 316404.10958904,  343561.64383562,  492928.08219178,
#         642294.52054795,  791660.95890411,  941027.39726027,
#         642294.52054795,  649898.63013699,  951618.83561644,
#         918215.06849315, 1102478.93835616])

# %%
p=lr.predict(d)

# %%
d['Prices']=p

# %%
d
# Out:
#     Area        Prices
# 0   1000  3.164041e+05
# 1   1200  3.435616e+05
# 2   2300  4.929281e+05
# 3   3400  6.422945e+05
# 4   4500  7.916610e+05
# 5   5600  9.410274e+05
# 6   3400  6.422945e+05
# 7   3456  6.498986e+05
# 8   5678  9.516188e+05
# 9   5432  9.182151e+05
# 10  6789  1.102479e+06

# %%
plt.xlabel('Area', fontsize=20)
plt.ylabel('Price', fontsize=20)

plt.scatter(df.Area, df.Price, color ='red')
plt.plot(df.Area, lr.predict(df[['Area']]))
